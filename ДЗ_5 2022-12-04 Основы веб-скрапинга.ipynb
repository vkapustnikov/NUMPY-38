# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime
import pandas as pd
import time

# %%
# Домашнее задание к лекции "Основы веб-скрапинга"
# Обязательная часть
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска 
# (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:

# <дата> - <заголовок> - <ссылка на материал>
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, 
# если они попадали в результаты поиска для нескольких запросов из списка.

# Дополнительная часть (необязательная)
# Функция из обязательной части задания должна быть расширена следующим образом:

# кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента 4 необходимо получить 
# материалы с первых 4 страниц результатов;
# в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>

# %%
# Решение обязательная часть
def habr_search(query):
    output = pd.DataFrame() # результаты
    for request in query:
        url = 'https://habr.com/ru/search/' # ссылка на habr
        params = {'q': request} # параметры
        res = requests.get(url, params=params) # затягиваем данные
        soup = BeautifulSoup(res.text) # варим суп
        articles = soup.find_all('article', class_='tm-articles-list__item') # все статьи
        
        for article in articles:
            date = datetime.strftime(datetime.strptime(article.find('span', class_='tm-article-snippet__datetime-published').time.get('datetime'), 
            '%Y-%m-%dT%H:%M:%S.000Z'), '%Y-%m-%d') # дата
            title = article.find('a', class_='tm-article-snippet__title-link').text # тема
            short_link = article.find('a', class_='tm-article-snippet__title-link').get('href') # краткая ссылка
            link = 'https://habr.com'+short_link # ссылка
            line = {'date': date, 'title': title, 'link': link}
            output = pd.concat([output, pd.DataFrame([line])])
            output.drop_duplicates('link', keep='first', inplace=True) # убрать дубликаты
            # output['dublicated'] = output.duplicated() # проверка на дубликаты
    return output.reset_index(drop=True) 

habr_search(['linux', 'python'])
# Out:
#           date                                              title  \
# 0   2020-05-06  Для ядра Linux предложили систему прозрачного ...
# 1   2021-04-19  В ядро Linux добавили начальную поддержку проц...
# 2   2022-11-24  «Администрирование Linux. Мега» — старт третье...
# 3   2020-08-19  Kali Linux получил графический интерфейс для п...
# 4   2022-10-28  «Администрирование Linux. Мега» — стартуем уже...
# 5   2022-11-01  Минцифры планирует определить три наиболее пер...
# 6   2020-06-28              Вышел Linux Mint 20 «Ulyana» (Ульяна)
# 7   2021-01-19  Corellium выпустила прототип порта Linux для с...
# 8   2021-03-27  Линус Торвальдс рассказал о том, где Rust впиш...
# 9   2021-08-13  Steam Deck будет работать на Arch Linux, а не ...
# 10  2020-09-28    Разработчик опубликовал DOS Subsystem for Linux
# 11  2020-10-21                     Вышел Microsoft Edge для Linux
# 12  2021-05-06  Microsoft выпустила бета-версию браузера Edge ...
# 13  2021-10-28  Intel Core i9 11900K: пять дистрибутивов Linux...
# 14  2022-01-24  Мы развернули платформу Deckhouse на узле с As...
# 15  2022-04-05       Платформа nanoCAD работает на ОС Astra Linux
# 16  2022-09-20  Минцифры изменит правила включения программ в ...
# 17  2022-12-02  Вышла Green Linux 21 — ОС на базе Linux Mint, ...
# 18  2020-08-21  Подсистема Windows для Linux 2 (WSL2) стала до...
# 19  2020-09-16  Microsoft представила патч Linux, с которым эт...
# 20  2022-01-20  Курс «Python для инженеров». Старт 3 потока 31...
# 21  2021-12-13  Жаждущим автоматизации: открытый урок «ChatOps...
# 22  2020-04-21  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 23  2021-07-06  Python Community Meetup 8/07: видео и материал...
# 24  2022-01-13  Открытый урок «Пишем Custom Prometheus Exporte...
# 25  2020-12-04  Python как компилируемый статически типизирова...
# 26  2022-03-08  Вышел мартовский релиз расширения Python для V...
# 27  2020-03-03  В начале этого года Python сместил Java и стал...
# 28  2021-11-16  EPAM разработала бесплатный курс по программир...
# 29  2022-08-19  Осталась неделя до старта 4 потока Python для ...
# 30  2020-06-03  Вышла версия 0.0.2 snakeware — дистрибутива Li...
# 31  2020-11-13  Создатель Python Гвидо ван Россум выходит на р...
# 32  2022-10-25                                  Вышел Python 3.11
# 33  2019-10-31  Создатель Python Гвидо ван Россум ушел из Drop...
# 34  2021-10-06          Вышел язык программирования Python 3.10.0
# 35  2021-10-11  Python вышел на первое место рейтинга TIOBE, и...
# 36  2022-06-03  «Тестирование веб-приложений на Python» — новы...
# 37  2022-08-24  Python, SQL, С и Java стали самыми популярными...
# 38  2022-12-05               Python или Golang: что учить в 2023?
# 39  2020-09-16  Астрономам порекомендовали меньше использовать...
#
#                                                  link
# 0   https://habr.com/ru/company/itsumma/news/t/500...
# 1   https://habr.com/ru/company/dcmiran/news/t/553...
# 2   https://habr.com/ru/company/southbridge/news/t...
# 3                  https://habr.com/ru/news/t/515726/
# 4   https://habr.com/ru/company/southbridge/news/t...
# 5                  https://habr.com/ru/news/t/696678/
# 6                  https://habr.com/ru/news/t/508570/
# 7                  https://habr.com/ru/news/t/538148/
# 8                  https://habr.com/ru/news/t/549266/
# 9    https://habr.com/ru/company/ruvds/news/t/572752/
# 10                 https://habr.com/ru/news/t/521066/
# 11                 https://habr.com/ru/news/t/524396/
# 12  https://habr.com/ru/company/itsumma/news/t/556...
# 13                 https://habr.com/ru/news/t/586132/
# 14   https://habr.com/ru/company/flant/news/t/646683/
# 15  https://habr.com/ru/company/nanosoft/news/t/65...
# 16                 https://habr.com/ru/news/t/689146/
# 17                 https://habr.com/ru/news/t/703118/
# 18                 https://habr.com/ru/news/t/516054/
# 19                 https://habr.com/ru/news/t/519308/
# 20  https://habr.com/ru/company/southbridge/news/t...
# 21  https://habr.com/ru/company/southbridge/news/t...
# 22                 https://habr.com/ru/news/t/498364/
# 23  https://habr.com/ru/company/raiffeisenbank/new...
# 24  https://habr.com/ru/company/southbridge/news/t...
# 25                 https://habr.com/ru/news/t/531402/
# 26                 https://habr.com/ru/news/t/654707/
# 27  https://habr.com/ru/company/itsumma/news/t/490...
# 28  https://habr.com/ru/company/epam_systems/news/...
# 29  https://habr.com/ru/company/southbridge/news/t...
# 30                 https://habr.com/ru/news/t/505096/
# 31                 https://habr.com/ru/news/t/527858/
# 32                 https://habr.com/ru/news/t/695298/
# 33                 https://habr.com/ru/news/t/473926/
# 34                 https://habr.com/ru/news/t/581862/
# 35                 https://habr.com/ru/news/t/582682/
# 36  https://habr.com/ru/company/yandex_praktikum/n...
# 37                 https://habr.com/ru/news/t/684376/
# 38  https://habr.com/ru/company/southbridge/news/t...
# 39                 https://habr.com/ru/news/t/519414/

# %%
# Решение дополнительная часть (частично)
# Как достать основной текст так и не разобрался
# там где он вроде должен быть не достаётся ничего:
#   soup.find_all('div', class_='article-formatted-body article-formatted-body article-formatted-body_version-1')
# буду благодарен за комментарии, как его нужно было доставать

def habr_search(query, page=1):
    output = pd.DataFrame() # результаты
    for request in query:
        params = {'q': request} # параметры
        
        for i in range(1, page+1):
            url = 'https://habr.com/ru/search/'+'page'+str(i)+'/' # ссылка на habr
            res = requests.get(url, params) # затягиваем данные
            soup = BeautifulSoup(res.text) # варим суп
            articles = soup.find_all('article', class_='tm-articles-list__item') # все статьи
            time.sleep(0.33) # торопиться не надо
            for article in articles:
                date = datetime.strftime(datetime.strptime(article.find('span', class_='tm-article-snippet__datetime-published').time.get('datetime'), 
                '%Y-%m-%dT%H:%M:%S.000Z'), '%Y-%m-%d') # дата
                title = article.find('a', class_='tm-article-snippet__title-link').text # тема
                short_link = article.find('a', class_='tm-article-snippet__title-link').get('href') # краткая ссылка
                link = 'https://habr.com'+short_link # ссылка
                line = {'date': date, 'title': title, 'link': link}
                output = pd.concat([output, pd.DataFrame([line])])
                output.drop_duplicates('link', keep='first', inplace=True) # убрать дубликаты
                # output['dublicated'] = output.duplicated() # проверка на дубликаты
    return output.reset_index(drop=True) 
    # return print(url)

habr_search(['linux', 'python'], 2)
# Out:
#           date                                              title  \
# 0   2020-05-06  Для ядра Linux предложили систему прозрачного ...
# 1   2021-04-19  В ядро Linux добавили начальную поддержку проц...
# 2   2022-11-24  «Администрирование Linux. Мега» — старт третье...
# 3   2020-08-19  Kali Linux получил графический интерфейс для п...
# 4   2022-10-28  «Администрирование Linux. Мега» — стартуем уже...
# ..         ...                                                ...
# 75  2022-09-19  Асинхронное программирование на Python для джу...
# 76  2022-11-08      Показываем полезное с Python meetup от Evrone
# 77  2021-12-08  Открытый семинар: FastAPI, или как быстро доба...
# 78  2022-04-18  Онлайн-митап от руководителя практики Python U...
# 79  2022-07-25  Бесплатный курс по бэкенд-разработке на Python...
#
#                                                  link
# 0   https://habr.com/ru/company/itsumma/news/t/500...
# 1   https://habr.com/ru/company/dcmiran/news/t/553...
# 2   https://habr.com/ru/company/southbridge/news/t...
# 3                  https://habr.com/ru/news/t/515726/
# 4   https://habr.com/ru/company/southbridge/news/t...
# ..                                                ...
# 75     https://habr.com/ru/company/kts/news/t/688988/
# 76  https://habr.com/ru/company/evrone/news/t/698054/
# 77                 https://habr.com/ru/news/t/594325/
# 78  https://habr.com/ru/company/usetech/news/t/661...
# 79  https://habr.com/ru/company/southbridge/news/t...
#
# [80 rows x 3 columns]

# %%
# тренировка
# url = 'https://habr.com/ru/search/?q=linux&target_type=posts&order=relevance' # ссылка на habr
# res = requests.get(url) # затягиваем данные
# soup = BeautifulSoup(res.text) # варим суп
# # search = soup.find_all('div' ,class_='tm-sub-page') # вся страница со статьями
# # search = soup.find_all('div', class_='tm-articles-list') # список статей
# # search = soup.find_all('article', class_='tm-articles-list__item')
# # search = soup.find('a', class_='tm-article-snippet__title-link').text # тема
# # search = soup.find('a', class_='tm-article-snippet__title-link').get('href') # краткая ссылка
# # search = datetime.strftime(datetime.strptime(soup.find('span', class_='tm-article-snippet__datetime-published').time.get('datetime'), '%Y-%m-%dT%H:%M:%S.000Z'), '%Y-%m-%d') # дата
# search = soup.find_all('div', class_='article-formatted-body article-formatted-body article-formatted-body_version-1') # текст
# print(search)
# print(soup)

# %%
# datetime.strftime(str(datetime.strptime(search, '%Y-%m-%dT%H:%M:%S.000Z')), '%Y-%m-%d')
